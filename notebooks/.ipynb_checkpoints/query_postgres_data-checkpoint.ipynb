# %%
# !pip install psycopg2-binary vaderSentiment nltk

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sqlalchemy import create_engine, text
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

postgres_dbname = 'clever'
postgres_user = 'clever'
postgres_password = 'clever'
postgres_host = 'postgres_clever'
postgres_port = '5432'

avaiable_tables = [
    'fmcsa_complaints',
    'fmcsa_safer_data',
    'fmcsa_company_snapshot',
    'fmcsa_companies',
    'customer_reviews_google',
    'company_profiles_google_maps'
]

engine = create_engine(
    f'postgresql+psycopg2://{postgres_user}:{postgres_password}@{postgres_host}:{postgres_port}/{postgres_dbname}'
)

with engine.connect() as conn:
    complaints_df = pd.read_sql('SELECT * FROM fmcsa_complaints', conn)
    safer_data_df = pd.read_sql('SELECT * FROM fmcsa_safer_data', conn)
    companies_df = pd.read_sql('SELECT * FROM fmcsa_companies', conn)
    company_snap = pd.read_sql('SELECT * FROM fmcsa_company_snapshot', conn)
    profiles_google_df = pd.read_sql('SELECT * FROM company_profiles_google_maps', conn)
    reviews_df = pd.read_sql('SELECT * FROM customer_reviews_google', conn)
    companies_join_safer_data = pd.read_sql("""SELECT cn.*, s.entity_type, s.legal_name, s.operating_status FROM fmcsa_companies cn
                                     LEFT JOIN fmcsa_safer_data s on cn.usdot_num = s.usdot_num 
                                    """, conn)
    profiles_google_reviews_df = pd.read_sql("""SELECT rg.review_datetime_utc, rg.google_id, rg.name, rg.review_text, rg.review_rating, rg.reviews, pg.city, pg.state FROM customer_reviews_google rg
                                     LEFT JOIN company_profiles_google_maps pg on rg.google_id = pg.google_id 
                                    """, conn)

# %%
# Ensure you download stopwords and punkt the first time.
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def rank_reviews(df, city=None, state=None):
    
    df['review_rating'] = pd.to_numeric(df['review_rating'], errors='coerce')
    df = df.dropna(subset=['review_rating'])

    df['reviews'] = pd.to_numeric(df['reviews'], errors='coerce')
    df = df.dropna(subset=['reviews'])

    df = df[(df['review_rating'].astype(float) >= 1) & (df['review_rating'].astype(float) <= 5)]


    df = df.groupby(['city','name'])[['review_rating','reviews']].mean().reset_index()

    df['score'] = (df['review_rating'] * df['reviews'])/100

    df = df.sort_values(by=['score'], ascending=False)
    return df

ranked_reviews = rank_reviews(profiles_google_reviews_df)
ranked_reviews['rank_all'] = ranked_reviews['score'].rank(ascending=False)
ranked_reviews['rank_city'] = ranked_reviews.groupby('city')['score'].rank(method='dense',ascending=False)
ranked_reviews.head(15)
# Out:
#        city                                           name  review_rating  \
# 13   Dallas                   Wrightway Moving Company LLC       4.747430
# 0    Dallas                              AM Moving Company       4.433649
# 9    Dallas    Phoenix Express Specialty Moving & Delivery       4.934959
# 12   Dallas          REAL Dallas Properties and Management       4.850267
# 5    Dallas                           Dallas Luxury Realty       4.696970
# 23    Miami                               Peak Cash Offers       4.723810
# 16    Miami                             Deals With Dignity       4.931034
# 7    Dallas                Housed Real Estate + Relocation       5.000000
# 39  Seattle                            Trelora Real Estate       4.596491
# 37  Seattle                                         Redfin       4.253521
# 14    Miami  Abraham Ash, Top 10 Florida Real Estate Agent       5.000000
# 17    Miami                                      Guestable       4.795918
# ...

# %%
stop_words = set(stopwords.words('english'))

df = profiles_google_reviews_df
df = df.loc[~df['review_text'].isnull()]

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    return text

df['cleaned_review_text'] = df['review_text'].apply(preprocess_text)

def analyze_sentiment(reviews):
    analyzer = SentimentIntensityAnalyzer()

    reviews['sentiment_score'] = reviews['review_text'].apply(lambda x: analyzer.polarity_scores(x)['compound'])

    reviews['sentiment_category'] = reviews['sentiment_score'].apply(
        lambda score: 'positive' if score > 0.1 else ('negative' if score < -0.1 else 'neutral')
    )
    return reviews

sentiment_analysis = analyze_sentiment(df)
sentiment_analysis.head(5)
# Out:
#   review_datetime_utc                              google_id  \
# 0      9/9/2023 22:50  0x864c26c8a3f9fe6f:0x9f5f2eee19038a8b
# 1      9/9/2023 22:00   0x864e99d71a97da87:0xacad6516b3a8297
# 2      9/9/2023 20:36  0x864c26c8a3f9fe6f:0x9f5f2eee19038a8b
# 3      9/9/2023 20:05  0x549015ed168dab6d:0x301820ce37c9de5b
# 4      9/9/2023 18:07  0x549015ed168dab6d:0x301820ce37c9de5b
#
#                                                        name  \
# 0                                   Wildcat Movers - Dallas
# 1                                                 AB Moving
# 2                                   Wildcat Movers - Dallas
# 3  Pure Moving Company Seattle Movers Local & Long distance
# 4  Pure Moving Company Seattle Movers Local & Long distance
#
# ...

# %%
df['year'] = pd.to_datetime(df['review_datetime_utc'], format='mixed').dt.year
grouped = sentiment_analysis.groupby(['year','name', 'sentiment_category']).agg(
    total_reviews=('review_text', 'size')
).reset_index()

df = grouped.pivot(index=['year','name'], columns='sentiment_category', values='total_reviews').fillna(0)

df.columns = ['neutral_reviews', 'negative_reviews', 'positive_reviews']

df['total_reviews'] = df['neutral_reviews'] + df['negative_reviews'] + df['positive_reviews']

sentiment_reviews_table = df.reset_index()
sentiment_reviews_table
# Out:
#        year                                        name  neutral_reviews  \
# 0    2010.0                        Dallas Luxury Realty              0.0
# 1    2011.0                        Dallas Luxury Realty              0.0
# 2    2012.0                        Dallas Luxury Realty              0.0
# 3    2012.0                            WaLaw Realty LLC              0.0
# 4    2013.0                           AM Moving Company              0.0
# ..      ...                                         ...              ...
# 449  2024.0                     Wildcat Movers - Dallas              1.0
# 450  2024.0                Wrightway Moving Company LLC              1.0
# 451  2024.0                      XPRESS RELOCATIONS LLC              1.0
# 452  2024.0  Zach McDonald - McDonald Real Estate Group              0.0
# 453  2024.0                                 investorade              0.0
#
#      negative_reviews  positive_reviews  total_reviews
# ...

# %%
top_n = 5

sentiment_reviews_table['percent_negative'] = (sentiment_reviews_table['negative_reviews'] / sentiment_reviews_table['total_reviews']) * 100

top_companies = sentiment_reviews_table.groupby('name')['total_reviews'].sum().nlargest(top_n).index

filtered_df = sentiment_reviews_table[sentiment_reviews_table['name'].isin(top_companies)]

plt.figure(figsize=(12, 8))

for company in filtered_df['name'].unique():
    company_data = filtered_df[filtered_df['name'] == company]
    plt.plot(company_data['year'], company_data['percent_negative'], label=f'{company} - Negative', marker='o', linestyle=':')

plt.title(f'Sentiment Evolution Over Years for Top {top_n} Companies', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Percentage of Reviews', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

for company in sentiment_reviews_table['name'].unique():
    company_data = sentiment_reviews_table[sentiment_reviews_table['name'] == company]
    plt.plot(company_data['year'], company_data['percent_negative'], label=f'{company} - Negative', marker='o', linestyle=':')

plt.title('Sentiment Evolution Over Years by Company', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Percentage of Reviews', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()
